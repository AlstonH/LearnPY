# %%
from pydantic import BaseModel,Field

#定義records裡的dict資料(最內層)
class Detail(BaseModel):
    name:str = Field(alias='Name_Ins')
    numbers:str = Field(alias='No')
    address:str = Field(alias='Address')
    tax:str = Field(alias='tax_ID_number')
    x:str = Field(alias='wgs84aX')
    y:str = Field(alias='wgs84aY')

#定義records的型態是list, 要抓取裡面的dict(中層)
class Fct_Menu(BaseModel):
    records:list[Detail]

#定義result底下的records資料 (外層)
class Fct_List(BaseModel):
    result:Fct_Menu

#開始解析json檔案
import json
with open("Newtaipeifood.json", encoding="utf-8") as file:
    content:str = file.read()
    data:list = Fct_List.model_validate_json(content)

    final:list[Detail] = data.result.records

#將資料一筆一筆抓出來
    for exam in final:
        print(exam)
print(f"總共抓取{len(final)}資料")
# Out:
# name='鴻輝食品廠' numbers='99611344' address='新北市新莊區新莊路四九三巷四弄一一號' tax='35567635' x='121.448618091317' y='25.0327031220478'
# name='廣達香食品股份有限公司' numbers='99604192' address='新北市新莊區化成路三八二巷一八號' tax='35549807' x='121.467221414508' y='25.04990297127'
# name='順發糧食行' numbers='99613990' address='新北市板橋區縣民大道一段二八一號' tax='33305209' x='121.460503814584' y='25.0101125037041'
# name='台灣塩野香料股份有限公司' numbers='99600477' address='新北市新莊區化成路二一九號' tax='03561504' x='121.465686254094' y='25.0467418103903'
# name='圓金釀造食品股份有限公司' numbers='99606467' address='新北市新莊區新樹路二六八巷二二號' tax='35427115' x='121.431057250618' y='25.0140290966789'
# name='永芳醬園股份有限公司' numbers='99605140' address='新北市永和區仁愛路一四一巷五二號' tax='33938534' x='121.512552729935' y='25.0113362727273'
# name='強生化學製藥廠股份有限公司' numbers='99606303' address='新北市三重區三和路4段77號2、3樓、79號1至6樓' tax='35348007' x='121.489724760043' y='25.0752712299029'
# name='大德製冰廠' numbers='99618950' address='新北市淡水區中正路二巷一號' tax='37011107' x='121.443662752774' y='25.1696653472412'
# ...

# %%
import json    
with open("Newtaipeifood.json", encoding="utf-8") as file:
    content:str = file.read()
    data:list = Fct_List.model_validate_json(content)
    print(type(content))
